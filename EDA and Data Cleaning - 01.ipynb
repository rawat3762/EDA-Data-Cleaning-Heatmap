# %% [markdown]
# # EDA and Data Cleaning with Heatmap

# %%
import pandas as pd
datasets = pd.read_csv(r'C:\Users\Ajay\OneDrive\Desktop\CRAFTEDGE DATASET\Loan payments data.csv')
datasets
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
datasets.head()
# Out:
#        Loan_ID loan_status  Principal  terms effective_date   due_date  \
# 0  xqd20166231     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 1  xqd20168902     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 2  xqd20160003     PAIDOFF       1000     30       9/8/2016  10/7/2016
# 3  xqd20160004     PAIDOFF       1000     15       9/8/2016  9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30       9/9/2016  10/8/2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1   10/7/2016 9:00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
datasets.shape
# Out:
# (500, 11)

# %%
datasets.isnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0      False        False      False  False           False     False
# 1      False        False      False  False           False     False
# 2      False        False      False  False           False     False
# 3      False        False      False  False           False     False
# 4      False        False      False  False           False     False
# ..       ...          ...        ...    ...             ...       ...
# 495    False        False      False  False           False     False
# 496    False        False      False  False           False     False
# 497    False        False      False  False           False     False
# 498    False        False      False  False           False     False
# 499    False        False      False  False           False     False
#
#      paid_off_time  past_due_days    age  education  Gender
# 0            False           True  False      False   False
# ...

# %%
datasets.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
datasets.shape[0]
# Out:
# 500

# %%
datasets.shape[1]
# Out:
# 11

# %%
datasets.isnull().sum().sum()
# Out:
# np.int64(400)

# %%
datasets.isnull().sum()/datasets.shape[0]*100
# Out:
# Loan_ID            0.0
# loan_status        0.0
# Principal          0.0
# terms              0.0
# effective_date     0.0
# due_date           0.0
# paid_off_time     20.0
# past_due_days     60.0
# age                0.0
# education          0.0
# Gender             0.0
# dtype: float64

# %%
(datasets.isnull().sum().sum()/(datasets.shape[0]*datasets.shape[1]))*100
# Out:
# np.float64(7.2727272727272725)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(datasets.isnull())
plt.show()

# %%
sns.heatmap(datasets.notnull())
plt.show()

# %%
datasets.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
datasets.drop(columns = ['past_due_days'],inplace = True)

# %%
datasets.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
sns.heatmap(datasets.isnull())
plt.show()

# %%
datasets.dropna(inplace = True)

# %%
sns.heatmap(datasets.isnull())
plt.show()
